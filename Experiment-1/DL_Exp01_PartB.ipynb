# %% [markdown]
# <a href="https://colab.research.google.com/github/rithishdev/DL_Lab/blob/main/DL_Exp01_PartB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Part B - ANN FOR CLASSIFICATION
#Dataset - Breast cancer dataset
#24BAD099 - Rithish A

import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# Load dataset
cancer = load_breast_cancer()
X_cls = pd.DataFrame(cancer.data, columns=cancer.feature_names)
y_cls = cancer.target

# Split dataset
X_train_c, X_test_c, y_train_c, y_test_c = train_test_split(
    X_cls, y_cls, test_size=0.2, random_state=42, stratify=y_cls
)

# Feature scaling
scaler_cls = StandardScaler()
X_train_c = scaler_cls.fit_transform(X_train_c)
X_test_c = scaler_cls.transform(X_test_c)

# Build ANN model
classification_model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation="relu", input_shape=(X_train_c.shape[1],)),
    tf.keras.layers.Dense(32, activation="relu"),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

# Compile model
classification_model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# Train model
classification_history = classification_model.fit(
    X_train_c,
    y_train_c,
    validation_split=0.2,
    epochs=50,
    batch_size=32,
    verbose=1
)

# Predict and evaluate
probabilities = classification_model.predict(X_test_c).ravel()
y_pred_c = (probabilities >= 0.5).astype(int)

accuracy = accuracy_score(y_test_c, y_pred_c)
precision = precision_score(y_test_c, y_pred_c)
recall = recall_score(y_test_c, y_pred_c)
f1 = f1_score(y_test_c, y_pred_c)
cm = confusion_matrix(y_test_c, y_pred_c)

print("\nClassification Evaluation")
print("-------------------------")
print("Accuracy :", accuracy)
print("Precision:", precision)
print("Recall   :", recall)
print("F1-score :", f1)
print("Confusion Matrix:\n", cm)
print("\nClassification Report:\n", classification_report(y_test_c, y_pred_c, target_names=cancer.target_names))

# Optional training curves
plt.figure(figsize=(10, 4))
plt.plot(classification_history.history["accuracy"], label="Training Accuracy")
plt.plot(classification_history.history["val_accuracy"], label="Validation Accuracy")
plt.title("Classification Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.7418 - loss: 0.4971 - val_accuracy: 0.8462 - val_loss: 0.4036
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8929 - loss: 0.3120 - val_accuracy: 0.9121 - val_loss: 0.2651
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9231 - loss: 0.2132 - val_accuracy: 0.9451 - val_loss: 0.1893
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9423 - loss: 0.1585 - val_accuracy: 0.9451 - val_loss: 0.1433
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9560 - loss: 0.1237 - val_accuracy: 0.9670 - val_loss: 0.1141
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9753 - loss: 0.1021 - val_accuracy: 0.9780 - val_loss: 0.0932
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9835 - loss: 0.0870 - val_accuracy: 0.9780 - val_loss: 0.0811
# Epoch 8/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9835 - loss: 0.0761 - val_accuracy: 0.9780 - val_loss: 0.0725
# Epoch 9/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9835 - loss: 0.0683 - val_accuracy: 0.9780 - val_loss: 0.0663
# Epoch 10/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9863 - loss: 0.0622 - val_accuracy: 0.9780 - val_loss: 0.0612
# Epoch 11/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9863 - loss: 0.0573 - val_accuracy: 0.9780 - val_loss: 0.0570
# Epoch 12/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9863 - loss: 0.0532 - val_accuracy: 0.9780 - val_loss: 0.0534
# Epoch 13/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9863 - loss: 0.0499 - val_accuracy: 0.9780 - val_loss: 0.0513
# Epoch 14/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9890 - loss: 0.0465 - val_accuracy: 0.9890 - val_loss: 0.0473
# Epoch 15/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9890 - loss: 0.0437 - val_accuracy: 0.9890 - val_loss: 0.0460
# Epoch 16/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9890 - loss: 0.0413 - val_accuracy: 0.9890 - val_loss: 0.0418
# Epoch 17/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9918 - loss: 0.0384 - val_accuracy: 0.9890 - val_loss: 0.0401
# Epoch 18/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9918 - loss: 0.0368 - val_accuracy: 0.9780 - val_loss: 0.0384
# Epoch 19/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9918 - loss: 0.0348 - val_accuracy: 1.0000 - val_loss: 0.0364
# Epoch 20/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9918 - loss: 0.0327 - val_accuracy: 1.0000 - val_loss: 0.0348
# Epoch 21/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9918 - loss: 0.0305 - val_accuracy: 1.0000 - val_loss: 0.0334
# Epoch 22/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9918 - loss: 0.0289 - val_accuracy: 1.0000 - val_loss: 0.0324
# Epoch 23/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9918 - loss: 0.0270 - val_accuracy: 1.0000 - val_loss: 0.0334
# Epoch 24/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9918 - loss: 0.0255 - val_accuracy: 1.0000 - val_loss: 0.0303
# Epoch 25/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9918 - loss: 0.0238 - val_accuracy: 1.0000 - val_loss: 0.0293
# Epoch 26/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9918 - loss: 0.0224 - val_accuracy: 1.0000 - val_loss: 0.0280
# Epoch 27/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9918 - loss: 0.0211 - val_accuracy: 1.0000 - val_loss: 0.0261
# Epoch 28/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9918 - loss: 0.0200 - val_accuracy: 1.0000 - val_loss: 0.0275
# Epoch 29/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9918 - loss: 0.0186 - val_accuracy: 1.0000 - val_loss: 0.0269
# Epoch 30/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9918 - loss: 0.0175 - val_accuracy: 1.0000 - val_loss: 0.0272
# Epoch 31/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9945 - loss: 0.0169 - val_accuracy: 1.0000 - val_loss: 0.0258
# Epoch 32/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9945 - loss: 0.0157 - val_accuracy: 1.0000 - val_loss: 0.0269
# Epoch 33/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9945 - loss: 0.0151 - val_accuracy: 1.0000 - val_loss: 0.0256
# Epoch 34/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9945 - loss: 0.0145 - val_accuracy: 1.0000 - val_loss: 0.0263
# Epoch 35/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0129 - val_accuracy: 1.0000 - val_loss: 0.0242
# Epoch 36/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9973 - loss: 0.0122 - val_accuracy: 1.0000 - val_loss: 0.0239
# Epoch 37/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9973 - loss: 0.0116 - val_accuracy: 1.0000 - val_loss: 0.0245
# Epoch 38/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.9890 - val_loss: 0.0260
# Epoch 39/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 1.0000 - val_loss: 0.0230
# Epoch 40/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 1.0000 - val_loss: 0.0218
# Epoch 41/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 0.0227
# Epoch 42/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.9890 - val_loss: 0.0244
# Epoch 43/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9973 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 0.0217
# Epoch 44/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 0.0237
# Epoch 45/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.9890 - val_loss: 0.0268
# Epoch 46/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.9890 - val_loss: 0.0248
# Epoch 47/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 1.0000 - val_loss: 0.0231
# Epoch 48/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.9890 - val_loss: 0.0243
# Epoch 49/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.9890 - val_loss: 0.0235
# Epoch 50/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.9890 - val_loss: 0.0227
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Classification Evaluation
# -------------------------
# Accuracy : 0.9736842105263158
# Precision: 0.9859154929577465
# Recall   : 0.9722222222222222
# F1-score : 0.9790209790209791
# Confusion Matrix:
#  [[41  1]
#  [ 2 70]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#    malignant       0.95      0.98      0.96        42
#       benign       0.99      0.97      0.98        72
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
